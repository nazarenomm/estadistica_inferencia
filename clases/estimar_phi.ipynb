# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# En la segunda imagen, si hubiera alpha se lo agrego al betas_log como en la imagen de arriba

# %% [markdown]
# ![image.png](attachment:image.png)
#
# l(phi) tambien depende de theta y los betas, etc. pero solo me interesa phi
#
# MPL es no sesgado, a diferencia de MLE

# %% [markdown]
# ![image.png](attachment:image.png)
