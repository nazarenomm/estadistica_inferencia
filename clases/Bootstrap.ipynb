# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
N = 1000
means = np.zeros(N)
for i in range(N):
  draws = np.random.wald(15,1000, size= 10)
  mean = np.mean(draws)
  means[i] = mean
plt.hist(means)
# Out:
# (array([ 12.,  47., 154., 259., 266., 167.,  63.,  24.,   6.,   2.]),
#  array([13.33441785, 13.73785872, 14.14129959, 14.54474046, 14.94818133,
#         15.3516222 , 15.75506307, 16.15850394, 16.56194481, 16.96538567,
#         17.36882654]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# En realidad yo medi esto

# %%
draws = np.random.wald(15, 1000, size=200)
plt.hist(draws)
# Out:
# (array([ 4., 15., 41., 38., 34., 27., 28.,  7.,  5.,  1.]),
#  array([10.90802213, 11.88747572, 12.86692931, 13.84638291, 14.8258365 ,
#         15.80529009, 16.78474368, 17.76419727, 18.74365086, 19.72310446,
#         20.70255805]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Bootstrap

# %%
N = 10000
bootstrap_means = np.zeros(N)
for i in range(N):
  mean = np.mean(np.random.choice(draws, size=len(draws), replace= True)) # size debe ser el mismo que en el muestreo original
  bootstrap_means[i] = mean
plt.hist(bootstrap_means)
# Out:
# (array([  26.,  173.,  768., 2104., 2962., 2485., 1099.,  328.,   52.,
#            3.]),
#  array([14.59313434, 14.6937705 , 14.79440665, 14.8950428 , 14.99567895,
#         15.0963151 , 15.19695125, 15.29758741, 15.39822356, 15.49885971,
#         15.59949586]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# No usar el bootstrap si tenemos dudas sobre la distribucion empirica.
# Si el bootstrap falla es dificil ver donde.

# %%
mean = np.mean(bootstrap_means)
mean
# Out:
# 15.0623849503682

# %%
sem = np.std(bootstrap_means)
sem # error estandar de la media
# Out:
# 0.13034087782622508

# %%
np.std(draws)/np.sqrt((len(draws) - 1))
# Out:
# 0.1308953710768959

# %% [markdown]
# Intervalos de confianza:

# %%
print(np.quantile(bootstrap_means, 0.025),
np.quantile(bootstrap_means, 0.975))
# Out:
# 14.80990283862479 15.324913867138036

# %% [markdown]
# bootstrap para std

# %%
N = 10000
bootstrap_stds = np.zeros(N)
for i in range(N):
  std = np.std(np.random.choice(draws, size=len(draws), replace= True)) # size debe ser el mismo que en el muestreo original
  bootstrap_stds[i] = std
plt.hist(bootstrap_stds)
# Out:
# (array([  12.,  113.,  622., 1731., 2873., 2737., 1400.,  422.,   77.,
#           13.]),
#  array([1.52488824, 1.58961641, 1.65434457, 1.71907273, 1.7838009 ,
#         1.84852906, 1.91325723, 1.97798539, 2.04271356, 2.10744172,
#         2.17216989]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# https://www.allendowney.com/blog/2024/04/17/what-does-a-confidence-interval-mean/
# leer
